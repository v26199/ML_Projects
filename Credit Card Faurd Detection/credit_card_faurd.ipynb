# %% [markdown]
# # Credit Card Faurd Detection

# %%
# importing required libraries.

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 153612   99611.0 -0.154484  0.156058  0.315805 -0.172057  1.000512 -1.179281
# 106012   69781.0 -0.674572 -0.059377  2.883432  1.363911 -1.404308  0.981621
# 159168  112290.0 -0.497263  1.196854 -0.805818 -0.607274  0.952043 -0.207704
# 179641  124172.0 -0.751419 -0.314512  0.659401 -3.024151 -0.863470 -0.492788
# 217047  140738.0  0.472644 -3.000853 -3.906707 -0.350163  0.108592 -0.792218
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 153612  0.972347 -0.612947  1.386070  ... -0.363949 -0.546238  0.424757
# 106012 -0.040102  0.486020  1.112282  ...  0.134654  0.656426  0.162541
# 159168  0.917910  0.386359 -0.510073  ...  0.117381  0.407223 -0.213597
# 179641 -0.618402  0.509677 -2.200920  ... -0.047089  0.149557 -0.121928
# 217047  1.932470 -0.653737  0.159877  ...  0.797721  0.389823 -1.000141
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.size
# Out:
# 8829017

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.Class.nunique()
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().mean() #check for missing values.
# Out:
# Time      0.0
# V1        0.0
# V2        0.0
# V3        0.0
# V4        0.0
# V5        0.0
# V6        0.0
# V7        0.0
# V8        0.0
# V9        0.0
# V10       0.0
# V11       0.0
# V12       0.0
# V13       0.0
# V14       0.0
# V15       0.0
# V16       0.0
# V17       0.0
# V18       0.0
# V19       0.0
# V20       0.0
# V21       0.0
# V22       0.0
# V23       0.0
# V24       0.0
# V25       0.0
# V26       0.0
# V27       0.0
# V28       0.0
# Amount    0.0
# Class     0.0
# dtype: float64

# %%
print(df['Class'].value_counts())
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df['Class']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %% [markdown]
# ## its clearly seen that, we have imbalanced dataset.

# %%
# Separate the features (X) and target variable (Y)
X = df.drop(columns='Class', axis=1)
y = df['Class']

y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %% [markdown]
# #### Deal with imbalace data

# %%
# !pip install imbalanced-learn


from imblearn.over_sampling import SMOTE
import pandas as pd

# Separate features and target variable
X = df.drop('Class', axis=1)
y = df['Class']

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to generate synthetic samples
X_resampled, y_resampled = smote.fit_resample(X, y)

# Concatenate resampled data into a new DataFrame
resampled_df = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['Class'])], axis=1)

# Display the class distribution after resampling
print(resampled_df['Class'].value_counts())
# Out:
# ...
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
# Split the data into training and testing sets (80% train, 20% test)
# 1. Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)
X_train.shape
# Out:
# (454904, 30)

# %%
X_test.shape
# Out:
# (113726, 30)

# %%
# performing scalling.

from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and testing data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# to reduce features and avoid colineariyt lets do PCA.

from sklearn.decomposition import PCA

# Initialize the PCA object
pca = PCA(n_components=0.95)  # Specify the desired explained variance ratio

# Fit PCA on the scaled training data and transform both training and testing data
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# Train the model
classifier = LogisticRegression()
classifier.fit(X_train_pca, y_train)

# Predictions on training set
train_pred = classifier.predict(X_train_pca)
train_accuracy = accuracy_score(y_train, train_pred)
print("Training Accuracy:", train_accuracy)

# Predictions on test set
test_pred = classifier.predict(X_test_pca)
test_accuracy = accuracy_score(y_test, test_pred)
print("Testing Accuracy:", test_accuracy)

# Classification report on test set
print(classification_report(y_test, test_pred))
# Out:
# Training Accuracy: 0.9722908569720204
# Testing Accuracy: 0.9726008124791164
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     56750
#            1       0.99      0.96      0.97     56976
#
#     accuracy                           0.97    113726
#    macro avg       0.97      0.97      0.97    113726
# weighted avg       0.97      0.97      0.97    113726

# %% [markdown]
# ## Let's check with all other classification model and then will compare all of them.

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import make_pipeline

def evaluate_classifiers(X_train, X_test, y_train, y_test):
    classifiers = {
        'Logistic Regression': LogisticRegression(),
        'Random Forest': RandomForestClassifier(),
    }

    for name, classifier in classifiers.items():
        print(f"Training and evaluating {name}...")

        # Define the pipeline
        pipeline = make_pipeline(
            SMOTE(random_state=42),
            StandardScaler(),
            PCA(n_components=0.95),
            classifier
        )

        # Train the model
        pipeline.fit(X_train, y_train)

        # Predictions on training set
        train_pred = pipeline.predict(X_train)
        train_accuracy = accuracy_score(y_train, train_pred)
        print(f"Training Accuracy ({name}): {train_accuracy:.4f}")

        # Predictions on test set
        test_pred = pipeline.predict(X_test)
        test_accuracy = accuracy_score(y_test, test_pred)
        print(f"Testing Accuracy ({name}): {test_accuracy:.4f}")

        # Classification report on test set
        print(f"Classification Report ({name}):\n{classification_report(y_test, test_pred)}")
        print('-' * 50)

# Example usage:
evaluate_classifiers(X_train, X_test, y_train, y_test)
# Out:
# Training and evaluating Support Vector Machine...

# %% [markdown]
# ### From the results obtained, we can draw the following conclusions and observations:
#
# #### Logistic Regression:
#
# Training Accuracy: 97.23%
# Testing Accuracy: 97.26%
# Precision, recall, and F1-score for both classes (0 and 1) are around 97%, indicating good performance.
# The model generalizes well to the test data without overfitting.
#
#
# #### Random Forest:
#
# Training Accuracy: 100.00%
# Testing Accuracy: 99.98%
# Precision, recall, and F1-score for both classes (0 and 1) are 100%, indicating excellent performance.
# The model performs exceptionally well on both the training and test data, potentially indicating overfitting on the training data.
# Observations:
#
# Both models, Logistic Regression and Random Forest, show very high accuracy on the test set, with Random Forest performing slightly better.
# Random Forest achieves perfect accuracy on the training set, which may indicate overfitting, while Logistic Regression achieves a slightly lower but still impressive accuracy.
# Precision, recall, and F1-score are consistently high for both models and both classes, indicating robust performance in classifying both fraudulent and non-fraudulent transactions.
# Random Forest tends to overfit more on the training data compared to Logistic Regression.
# Despite the differences in complexity and performance, both models perform well on this dataset, suggesting that either approach could be suitable for credit card fraud detection. However, Logistic Regression may be preferred due to its simplicity and interpretability unless higher performance is critical and overfitting can be carefully managed.
